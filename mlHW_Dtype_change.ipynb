# %% [markdown]
# <a href="https://colab.research.google.com/github/FunSizeNanoByte/kitkats/blob/Collab/mlHW_Dtype_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Upload the dataset to Google Colab and change the "test_preparation_course" into categorical variable.

# %%
#file upload
df = pd.read_csv('student (1).csv')
df.head(6)
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
# 5  female   group B  associate's degree      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75
# 5          71             83             78

# %%
df['test_preparation_course'] = df['test_preparation_course'].astype('category')
df.dtypes
df.head()
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## 2. Use value_counts() function to find out the how many students participated the "test_preparation_course" and how many did not.

# %%
df['test_preparation_course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test_preparation_course, dtype: int64

# %% [markdown]
# this shows 358 students took the test prep course

# %% [markdown]
# ## 3. Let's create a data visualization by using Python. Create a histogram to show the distribution of "reading_score".

# %%
df['reading_score'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Create a new data frame called df_new. In this data frame, you need to transform two variables (gender & test_preparation_course) to dummy variables and drop first columns.

# %%
#reference
#professor jessica's mutliple variable change example
# dummied_df = pd.get_dummies(df, columns=['ethnicity','gender'], drop_first=True)
df_new = pd.get_dummies(df, columns=['gender','test_preparation_course'],drop_first=True)

# %%
df_new.head()
# Out:
#   ethnicity  parental_education         lunch  math_score  reading_score  \
# 0   group B   bachelor's degree      standard          72             72
# 1   group C        some college      standard          69             90
# 2   group B     master's degree      standard          90             95
# 3   group A  associate's degree  free/reduced          47             57
# 4   group C        some college      standard          76             78
#
#    writing_score  gender_male  test_preparation_course_none
# 0             74            0                             1
# 1             88            0                             0
# 2             93            0                             1
# 3             44            1                             1
# 4             75            1                             1

# %% [markdown]
# ## 5. After you complete these tasks, transform your ipynb file to html file, and upload the html file to the box down below. You can also submit the pdf, but I prefer html format.

# %%
# !jupyter nbconvert --to html 'mlHW_1.ipynb'
# Out:
# [NbConvertApp] Converting notebook mlHW_1.ipynb to html
# [NbConvertApp] Writing 623314 bytes to mlHW_1.html
